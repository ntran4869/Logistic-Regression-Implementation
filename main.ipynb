# %%
from mylogistic import MyLogisticRegression
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("diabetes.csv")
y = df['Outcome']
x = df.drop('Outcome', axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# %%
clf = MyLogisticRegression()
clf.train(X_train,y_train)
# Out:
# Training model: 100%|██████████| 50/50 [00:00<00:00, 126.30it/s]

# %%
plt.plot(clf.losses)
plt.title("Log-Loss overtime")
plt.xlabel("Epochs")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')

# %%
plt.plot(clf.train_accuracies)
plt.title("Training accuracy overtime")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
# predictions
pred = clf.predict(X_test)
acc = accuracy_score(y_test, pred)
print(acc)
# Out:
# 0.6041666666666666

# %%
from sklearn.linear_model import LogisticRegression

clf2 = LogisticRegression()
clf2.fit(X_train,y_train)
pred2 = clf2.predict(X_test)
acc2 = accuracy_score(y_test, pred2)
print(acc2)
# Out:
# 0.7291666666666666
# c:\Users\Nguyen Tran\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
